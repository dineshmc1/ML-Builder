# %% [markdown]
# # Exploratory Data Analysis\n**Dataset**: `C:\Dinesh\Datasets\MBMB_TAX.csv`\n\nThis notebook was auto-generated by the MetaAutoML Data Understanding Agent.

# %%
import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nimport warnings\nwarnings.filterwarnings('ignore')\n\nsns.set_theme(style='whitegrid')

# %%
df = pd.read_csv('C:\Dinesh\Datasets\MBMB_TAX.csv')\ndf.head()

# %%
print(f"Dataset Shape: {df.shape}")\nprint("\\nMissing Values:")\nprint(df.isnull().sum()[df.isnull().sum() > 0])

# %%
plt.figure(figsize=(10, 6))\nsns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')\nplt.title('Missing Values Heatmap')\nplt.show()

# %% [markdown]
# ## Target Analysis: `original_jumlah`

# %%
plt.figure(figsize=(8, 5))\nsns.histplot(data=df, x='original_jumlah', kde=True, color='blue')\nplt.title('Target Distribution')\nplt.show()

# %% [markdown]
# ## Correlation Analysis (Numeric Features)

# %%
numeric_df = df.select_dtypes(include=[np.number])\nif not numeric_df.empty and numeric_df.shape[1] > 1:\n    plt.figure(figsize=(12, 8))\n    corr = numeric_df.corr()\n    sns.heatmap(corr, annot=False, cmap='coolwarm', center=0)\n    plt.title('Numeric Correlation Matrix')\n    plt.show()\nelse:\n    print("Not enough numeric columns for correlation matrix.")

# %% [markdown]
# ## AI Insights\n- Missing values in columns such as status_waran, status_peguam, and catitan1 to catitan4. High cardinality in ID columns like masked_no_akaun, masked_no_kp, and masked_no_bil.\n
